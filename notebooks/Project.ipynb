# %%
import pandas as pd

# %%
aqar = pd.read_csv('SA_Aqar.csv')

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3718 entries, 0 to 3717
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          3718 non-null   object
#  1   district      3718 non-null   object
#  2   front         3718 non-null   object
#  3   size          3718 non-null   int64
#  4   property_age  3718 non-null   int64
#  5   bedrooms      3718 non-null   int64
#  6   bathrooms     3718 non-null   int64
#  7   livingrooms   3718 non-null   int64
#  8   kitchen       3718 non-null   int64
#  9   garage        3718 non-null   int64
#  10  driver_room   3718 non-null   int64
#  11  maid_room     3718 non-null   int64
#  12  furnished     3718 non-null   int64
#  13  ac            3718 non-null   int64
#  14  roof          3718 non-null   int64
#  15  pool          3718 non-null   int64
#  16  frontyard     3718 non-null   int64
#  17  basement      3718 non-null   int64
# ...

# %%
aqar.isnull().sum()
# Out:
# city             0
# district         0
# front            0
# size             0
# property_age     0
# bedrooms         0
# bathrooms        0
# livingrooms      0
# kitchen          0
# garage           0
# driver_room      0
# maid_room        0
# furnished        0
# ac               0
# roof             0
# pool             0
# frontyard        0
# basement         0
# duplex           0
# stairs           0
# elevator         0
# fireplace        0
# price            0
# details         80
# dtype: int64

# %%
aqar['details']
# Out:
# 0       للايجار فيلا دبلكس في موقع ممتاز جدا بالقرب من...
# 1       *** فيلا درج مع الصالة جديدة ***\n\nعبارة عن م...
# 2       فيلا للايجار درج داخلي مشب خارجي مجلس مقلط وصا...
# 3       فيلا للايجار        جديده لن تستخدم          ش...
# 4       فيلا للايجار حي العليا \n\nالارضي مجالس وغرفتي...
#                               ...
# 3713    للإيجار فيلا دورين وملحق في حي الأصداف\n\nالمس...
# 3714    دبلكس للأيجار حي الصواري ج ٤٣\n\nمجلس خارجي (د...
# 3715    حوش مجلس خارجي مجلس رجال دورة مياة مجلط  صاله ...
# 3716    فيلا فاخرة في حي كورنيش الخبر. أفضل حي بالخبر....
# 3717    للأيجار ڤيلا دورين و ملحق في حي الأصداف\n\nالم...
# Name: details, Length: 3718, dtype: object

# %%
aqar.dropna(inplace=True)
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar.describe()
# Out:
#                size  property_age     bedrooms    bathrooms  livingrooms  \
# count   3638.000000   3638.000000  3638.000000  3638.000000  3638.000000
# mean     391.669049      5.075866     5.085487     4.602529     2.244365
# std     1581.657156      7.583230     1.235130     0.705697     0.919911
# min        1.000000      0.000000     1.000000     1.000000     1.000000
# 25%      275.250000      0.000000     4.000000     4.000000     2.000000
# 50%      330.000000      2.000000     5.000000     5.000000     2.000000
# 75%      400.000000      7.000000     6.000000     5.000000     3.000000
# max    95000.000000     36.000000     7.000000     5.000000     5.000000
#
#            kitchen       garage  driver_room    maid_room    furnished  \
# count  3638.000000  3638.000000  3638.000000  3638.000000  3638.000000
# mean      0.908191     0.799890     0.491754     0.795492     0.115173
# std       0.288795     0.400137     0.500001     0.403397     0.319275
# ...

# %%
aqar['kitchen'].value_counts()
# Out:
# kitchen
# 1    3304
# 0     334
# Name: count, dtype: int64

# %%
dic={0:'No',1:'Yes'}

# %%
aqar['elevator']=aqar['elevator'].map(dic)

# %%
aqar['fireplace']=aqar['fireplace'].map(dic)

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar.columns
# Out:
# Index(['city', 'district', 'front', 'size', 'property_age', 'bedrooms',
#        'bathrooms', 'livingrooms', 'kitchen', 'garage', 'driver_room',
#        'maid_room', 'furnished', 'ac', 'roof', 'pool', 'frontyard', 'basement',
#        'duplex', 'stairs', 'elevator', 'fireplace', 'price', 'details'],
#       dtype='object')

# %%
aqar['stairs']=aqar['stairs'].map(dic)

# %%
aqar['duplex']=aqar['duplex'].map(dic)

# %%
aqar['basement'].value_counts()
# Out:
# basement
# 0    3515
# 1     123
# Name: count, dtype: int64

# %%
aqar['basement']=aqar['basement'].map(dic)

# %%
aqar['frontyard'].value_counts()
# Out:
# frontyard
# 1    2913
# 0     725
# Name: count, dtype: int64

# %%
aqar['frontyard']=aqar['frontyard'].map(dic)

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar['pool'].value_counts()
# Out:
# pool
# 0    3075
# 1     563
# Name: count, dtype: int64

# %%
aqar['roof'].value_counts()
# Out:
# roof
# 1    1889
# 0    1749
# Name: count, dtype: int64

# %%
aqar['ac'].value_counts()
# Out:
# ac
# 1    2027
# 0    1611
# Name: count, dtype: int64

# %%
aqar[['garage', 'driver_room',
       'maid_room', 'furnished']].value_counts()
# Out:
# garage  driver_room  maid_room  furnished
# 1       1            1          0            1299
#         0            1          0             850
# 0       0            0          0             272
# 1       0            0          0             270
# 0       0            1          0             206
#         1            1          0             188
# 1       1            1          1             158
#         0            1          1             154
#         1            0          0             117
#         0            0          1              58
# 0       0            1          1              34
#         1            0          0              17
#         0            0          1               5
#         1            1          1               5
# 1       1            0          1               4
# 0       1            0          1               1
# Name: count, dtype: int64

# %%
aqar['garage']=aqar['garage'].map(dic)

# %%
aqar['driver_room']=aqar['driver_room'].map(dic)

# %%
aqar['maid_room']=aqar['maid_room'].map(dic)

# %%
aqar['furnished']=aqar['furnished'].map(dic)

# %%
aqar[['roof', 'pool']].value_counts()
# Out:
# roof  pool
# 1     0       1647
# 0     0       1428
#       1        321
# 1     1        242
# Name: count, dtype: int64

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar['roof']=aqar['roof'].map(dic)

# %%
aqar['pool']=aqar['pool'].map(dic)

# %%
aqar.columns
# Out:
# Index(['city', 'district', 'front', 'size', 'property_age', 'bedrooms',
#        'bathrooms', 'livingrooms', 'kitchen', 'garage', 'driver_room',
#        'maid_room', 'furnished', 'ac', 'roof', 'pool', 'frontyard', 'basement',
#        'duplex', 'stairs', 'elevator', 'fireplace', 'price', 'details'],
#       dtype='object')

# %%
aqar.kitchen.value_counts()
# Out:
# kitchen
# 1    3304
# 0     334
# Name: count, dtype: int64

# %%
aqar['kitchen']=aqar['kitchen'].map(dic)

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar.price.value_counts()
# Out:
# price
# 60000     321
# 80000     308
# 65000     232
# 100000    196
# 90000     193
#          ...
# 600000      1
# 780000      1
# 67000       1
# 7500        1
# 49950       1
# Name: count, Length: 112, dtype: int64

# %%
aqar.iloc[3715]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 aqar.iloc[3715]
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
# ...

# %%
namenew={'kitchen':'extra kitchen'}
aqar=aqar.rename(columns=namenew)

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3715    الخبر       حي اللؤلؤ    غرب   330             0         6          4
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...

# %%
aqar['size'].sort_values()
# Out:
# 1126        1
# 1832      100
# 1662      100
# 1798      100
# 1781      100
#         ...
# 535      2944
# 99       3000
# 209      3060
# 1323     5000
# 997     95000
# Name: size, Length: 3638, dtype: int64

# %%
aqar=aqar.drop(1126)

# %%
aqar['size'].sort_values()
# Out:
# 1526      100
# 1543      100
# 1509      100
# 1696      100
# 1458      100
#         ...
# 535      2944
# 99       3000
# 209      3060
# 1323     5000
# 997     95000
# Name: size, Length: 3637, dtype: int64

# %%
# 
filt2=aqar[(aqar['duplex']=='Yes') & (aqar['stairs'] == 'No') & (aqar['elevator'] == 'No')] 
filt3=filt2.index.tolist()

# %%
aqar=aqar.drop(index=filt3)

# %%
aqar
# Out:
#          city         district front  size  property_age  bedrooms  bathrooms  \
# 0      الرياض       حي العارض   شمال   250             0         5          5
# 1      الرياض     حي القادسية   جنوب   370             0         4          5
# 2      الرياض     حي القادسية   جنوب   380             0         4          5
# 3      الرياض     حي المعيزلة    غرب   250             0         5          5
# 4      الرياض       حي العليا    غرب   400            11         7          5
# ...       ...              ...   ...   ...           ...       ...        ...
# 3712    الخبر      حي التحلية    شرق   330             0         4          5
# 3713    الخبر       حي اللؤلؤ    غرب   437             0         7          5
# 3714    الخبر      حي الصواري   جنوب   400             0         5          5
# 3716    الخبر     حي الكورنيش   جنوب   300            13         6          5
# 3717    الخبر      حي الامواج    غرب   437             0         7          5
#
# ...
